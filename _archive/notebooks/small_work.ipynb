# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ppg-bp_data_online.csv")
# Out:
# C:\Users\Ridwan Sharif\AppData\Local\Temp\ipykernel_676\4116823644.py:1: DtypeWarning: Columns (10509,10510,10511) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("ppg-bp_data_online.csv")

# %%
display(df.head())
# Out:
#     PPG_1   PPG_2   PPG_3   PPG_4   PPG_5   PPG_6   PPG_7   PPG_8   PPG_9  \
# 0  2438.0  2438.0  2438.0  2455.0  2455.0  2384.0  2384.0  2384.0  2418.0
# 1  1973.0  1973.0  1990.0  1990.0  1979.0  1979.0  1979.0  1956.0  1956.0
# 2  2003.0  2003.0  1978.0  1978.0  1978.0  1993.0  1993.0  1986.0  1986.0
# 3  2039.0  2039.0  2039.0  2029.0  2029.0  2042.0  2042.0  2042.0  2044.0
# 4  1961.0  1971.0  1971.0  1971.0  1964.0  1964.0  1968.0  1968.0  1968.0
#
#    PPG_10  ...  Height(cm)  Weight(kg)  Systolic Blood Pressure(mmHg)  \
# 0  2418.0  ...         152          63                            161
# 1  1965.0  ...         157          50                            160
# 2  1986.0  ...         150          47                            101
# 3  2044.0  ...         172          65                            136
# 4  1994.0  ...         155          65                            123
#
#    Diastolic Blood Pressure(mmHg)  Heart Rate(b/m)  BMI(kg/m^2)  \
# ...
